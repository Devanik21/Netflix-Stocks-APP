# %%
from pandas import  *
from numpy import *
from seaborn import *
from matplotlib.pyplot import *
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
df=read_csv('NFLX.csv')

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
df=df.drop(columns='Date')

# %%
x=df.drop(columns='Close')

# %%
x.columns
# Out:
# Index(['Open', 'High', 'Low', 'Adj Close', 'Volume'], dtype='object')

# %%
y=df[['Close']]

# %% [markdown]
# RF

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
from sklearn.ensemble import RandomForestRegressor
r=RandomForestRegressor(n_estimators=100)
r.fit(x_train,y_train)
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
r.score(x_train,y_train)
# Out:
# 0.9999761960719327

# %%
r.score(x_test,y_test)
# Out:
# 0.9997538761441715

# %%
r.predict([[262.00,267.894,250.029,254.255,11896100]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([255.63222964])

# %% [markdown]
# 254 is accurate

# %% [markdown]
# DT

# %%
from sklearn.tree import  DecisionTreeRegressor
d=DecisionTreeRegressor()
d.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
d.score(x_train,y_train)
# Out:
# 1.0

# %%
d.score(x_test,y_test)
# Out:
# 0.9996512800550738

# %%
d.predict([[262.00,267.894,250.029,254.255,11896100]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([254.255])

# %% [markdown]
# Accurate !

# %% [markdown]
# Now, ET

# %%
'''from sklearn.ensemble import ExtraTreesRegressor
e=ExtraTreesRegressor(n_estimators=100)
e.fit(x_train,y_train)'''
# Out:
# 'from sklearn.ensemble import ExtraTreesRegressor\ne=ExtraTreesRegressor(n_estimators=100)\ne.fit(x_train,y_train)'

# %%
import joblib
#loading The models anywhere

e=joblib.load('Netflix Stocks ET.pkl')

# %%
e.score(x_train,y_train)
# Out:
# 1.0

# %%
e.score(x_test,y_test)
# Out:
# 0.99979915998362

# %%
#saving The Models

#joblib.dump(e,'Netflix Stocks ET.pkl')

# %%
e.predict([[262.00,267.894,250.029,254.255,11896100]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but ExtraTreesRegressor was fitted with feature names
#   warnings.warn(
# array([254.255])

# %% [markdown]
# Accurate!

# %% [markdown]
# Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingRegressor
g=GradientBoostingRegressor(n_estimators=100)
g.fit(x_train,y_train)
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\ensemble\_gb.py:668: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)  # TODO: Is this still required?
# GradientBoostingRegressor()

# %%
g.score(x_train,y_train)
# Out:
# 0.9999679106657974

# %%
g.score(x_test,y_test)
# Out:
# 0.9997562114211478

# %%
g.predict([[262.00,267.894,250.029,254.255,11896100]])
# Out:
# c:\Users\debna\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([254.45724632])

# %% [markdown]
# Catboost

# %%
from catboost import  CatBoostRegressor,CatBoostClassifier

# %%
c=CatBoostRegressor(learning_rate=1,n_estimators=1000)
c.fit(x_train,y_train)
# Out:
# 0:	learn: 22.7143915	total: 5.29ms	remaining: 5.28s
# 1:	learn: 17.7002354	total: 8.27ms	remaining: 4.13s
# 2:	learn: 16.2381256	total: 10.2ms	remaining: 3.38s
# 3:	learn: 14.6976261	total: 12ms	remaining: 2.98s
# 4:	learn: 11.5299072	total: 13.3ms	remaining: 2.64s
# 5:	learn: 10.3233681	total: 14.5ms	remaining: 2.4s
# 6:	learn: 10.0116994	total: 15.7ms	remaining: 2.23s
# 7:	learn: 9.0302567	total: 17.2ms	remaining: 2.13s
# 8:	learn: 8.7393070	total: 18.6ms	remaining: 2.05s
# 9:	learn: 8.0928051	total: 19.9ms	remaining: 1.97s
# 10:	learn: 7.9543469	total: 21.3ms	remaining: 1.92s
# 11:	learn: 7.4808230	total: 22.8ms	remaining: 1.87s
# 12:	learn: 6.4414749	total: 24.4ms	remaining: 1.85s
# 13:	learn: 6.2897175	total: 25.7ms	remaining: 1.81s
# 14:	learn: 5.7385524	total: 26.7ms	remaining: 1.76s
# 15:	learn: 5.4903335	total: 27.8ms	remaining: 1.71s
# 16:	learn: 5.3257477	total: 28.9ms	remaining: 1.67s
# 17:	learn: 5.2001654	total: 30.3ms	remaining: 1.65s
# ...

# %%
c.score(x_train,y_train)
# Out:
# 0.9999999999947741

# %%
c.score(x_test,y_test)
# Out:
# 0.9962603686341682

# %%
c.predict([[262.00,267.894,250.029,254.255,11896100]])
# Out:
# array([254.25494071])

# %% [markdown]
# LGBM

# %%
from  lightgbm import *

# %%
# Initialize the LightGBM classifier
l = LGBMRegressor(n_estimators=1000, learning_rate=1)
l.fit(x_train, y_train)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004719 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1180
# [LightGBM] [Info] Number of data points in the train set: 706, number of used features: 5
# [LightGBM] [Info] Start training from score 416.138769
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %%
l.score(x_train,y_train)
# Out:
# 0.9998128692869234

# %%
l.score(x_test,y_test)
# Out:
# 0.9966843605017052

# %%
l.predict([[262.00,267.894,250.029,254.255,11896100]])
# Out:
# array([254.25566577])

# %% [markdown]
# Accurate !

# %% [markdown]
# RF < GB < DT = ET = CAT  = LGBM
